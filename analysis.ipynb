# %%
# imports
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
# Dataframe with all unique tweets
df = pd.read_parquet('/home/PS_XBox_Data/all_tweets.parquet')

df.head(2)
# Out:
#                        date  \
# 0 2010-06-13 23:58:21+00:00
# 1 2010-06-13 23:47:14+00:00
#
#                                           rawContent           id  replyCount  \
# 0  De casualidad alguien tendra instalados juegos...  16106387748           0
# 1  The fact that I'm working 6 days a week brings...  16105780562           0
#
#    retweetCount  likeCount  quoteCount lang hashtags        name    location  \
# 0             0          0           0   es     <NA>  Mœntenegro  Hermosillo
# 1             0          0           0   en     <NA>      Luis B         NYC
#
#   language                                              tweet  \
# 0  Spanish  De casualidad alguien tendra instalados juegos...
# 1  English  The fact that I'm working 6 days a week brings...
#
#                                          clean_tweet  \
# 0  De casualidad alguien tendra instalados juegos...
# 1  The fact that I'm working 6 days a week brings...
#
# ...

# %%
# Number of tweets per brand and month

# Create the base figure
fig_1 = go.Figure()

# Add traces for each brand
fig_1.add_trace(go.Scatter(
    x=df[df.Brand == 'Playstation']['date'].resample('M', on='date'),
    y=df[df.Brand == 'Playstation']['date', 'Brand'].resample(
        'M', on='date').count()['Brand'],
    mode='lines',
    line=dict(width=0.5, color='#003791'),
    fill='tozeroy',
    hoverinfo='x+y',    
))

fig_1.add_trace(go.Scatter(
    x=df[df.Brand == 'Xbox']['date'].resample('M', on='date'),
    y=df[df.Brand == 'Xbox']['date', 'Brand'].resample(
        'M', on='date').count()['Brand'],
    mode='lines',
    line=dict(width=0.5, color='#107C10'),
    fill='tozeroy',
    hoverinfo='x+y',
))

fig_1.add_trace(go.Scatter(
    x=df[df.Brand == 'PS/Xbox']['date'].resample('M', on='date'),
    y=df[df.Brand == 'PS/Xbox']['date', 'Brand'].resample(
        'M', on='date').count()['Brand'],
    mode='lines',
    line=dict(width=0.5, color='#9C50B6'),
    fill='tozeroy',
    hoverinfo='x+y',
))
